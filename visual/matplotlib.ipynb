# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.ticker as ticker
import matplotlib.cm as cm
import matplotlib.colors as col

# %%
x = range(100)
y = [value ** 2 for value in x]

plt.plot(x,y)
plt.show()

# %%
t =range(100)
x = [(2*math.pi*T)/len(t) for T in t]
y = [math.sin(value)for value in x]
plt.plot(x,y)
plt.show()

# %%
x = np.linspace(0,2*np.pi,100)
ya = np.sin(x)
yb = np.cos(x)

plt.plot(x,ya)
plt.plot(x,yb)
plt.show()

# %%
plt.scatter(data[:,0],data[:,1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-b88627b76b25> in <module>
# ----> 1 plt.scatter(data[:,0],data[:,1])
#
# NameError: name 'data' is not defined

# %%
data = [5., 20., 50., 25.]
plt.bar(range(len(data)),data)
plt.show()

# %%
data
# Out:
# [5.0, 20.0, 50.0, 25.0]

# %%
#수평 막대
plt.barh(range(len(data)),data)
plt.show()

# %%
#다중 막대 차트 그리기
data = [[5, 25, 50, 20],
        [4, 23, 51, 17],
       [6, 22, 52, 19]]
x= np.arange(4)
plt.bar(x,data[0],color='b',width=0.25)
plt.bar(x+0.25,data[1],color='g',width=0.25)
plt.bar(x+0.5,data[2],color='r',width=0.25)
# Out:
# <BarContainer object of 4 artists>

# %%
#bottom 옵션을 주어 일직선으로 쌓기
a = [ 5, 30, 45, 22]
b= [5, 25 ,50 ,20]
x = range(4)
plt.bar(x,a, color='b')
plt.bar(x,b, color='r', bottom=a)
plt.show()

# %%
women_pop = np.array([5, 30, 45, 22])
men_pop = np.array([5, 25, 50, 20])
x = np.arange(4)

plt.barh(x , women_pop,  color='r')
plt.barh(x, -men_pop, color='b')
plt.show()

# %%
data = [5, 25, 50, 20]
plt.pie(data)
plt.show()

# %%
x = np.random.randn(1000)

plt.hist(x,bins = 20)
plt.show()

# %%
x = np.random.randn(100)

plt.boxplot(x)
plt.show()

# %%
data = np.random.randn(100,5)

plt.boxplot(data)
plt.show()

# %%
color = ['b','g','r','c','m','y','k','w']

def pdf(x, mu, sigma):
    a = 1./(sigma* np.sqrt(2.*np.pi))
    b = -1/(2*sigma**2)
    return a* np.exp(b*(x-mu)**2)

x = np.linspace(-6,6,1000)
for i in range(5):
    samples = np.random.standard_normal(50)
    mu, sigma = np.mean(samples), np.std(samples)
    plt.plot(x, pdf(x,0,1),color='k')

# %%
a = np.random.standard_normal((100,2))
a += np.array((-1,-1))

b = np.random.standard_normal((100,2))
b += np.array((1,1))

plt.scatter(a[:,0],a[:,1], color ='0.25')
plt.scatter(b[:,0],b[:,1], color ='0.75')
plt.show()

# %%
N = 256
angle = np.linspace(0,8*2*np.pi,N)
radius = np.linspace(0.5,1,N)

x = radius * np.cos(angle)
y = radius * np.sin(angle)

plt.scatter(x,y, c = angle, cmap = cm.hsv) 
#cm.hsv가 무지개처럼 보여주는 color맵 제공
plt.show()

# %%
values = np.random.random_integers(99, size=50)

cmap = cm.ScalarMappable(col.Normalize(0,99),cm.binary)
plt.bar(np.arange(len(values)), values, color = cmap.to_rgba(values))
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: This function is deprecated. Please call randint(1, 99 + 1) instead
#   """Entry point for launching an IPython kernel.

# %%
def pdf(x,mu,sigma):
    a = 1
    b = -1
    return a * np.exp(b*(x-mu)**2)

x = np.linspace(-6,6,1024)

# dashed 파선, solid 실선, dotted 점선, dashdot 쇄선

plt.plot(x, pdf(x,0,1),color='k', linestyle='dashed', linewidth=3)

# %%
N = 8
a = np.random.random(N)
b = np.random.random(N)
x = np.arange(N)

plt.bar(x,a, color ='g')
plt.bar(x,b+a,bottom=a, linestyle='solid', linewidth=0.5)
plt.show()

# %%
plt.bar(x,a,color='w',hatch='x')
plt.bar(x,a+b,bottom=a,color='w',hatch='/')
plt.show()

# %%
x = np.linspace(-4,4,1024)
y =0.25 *(x+4)*(x+1)*(x-2)

plt.title('A polynomial')
plt.plot(x,y, c ='k')
plt.show()

# %%
plt.title('Power curve for airfoil KV873')
plt.xlabel('Air speed')
plt.ylabel('Total drag')
plt.plot(x,y,c='k')
plt.show()

# %%
x=np.linspace(0,6, 1024)
y1 = np.sin(x)
y2 = np.cos(x)
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x,y1, c='k', label='sin(x)',lw=3)
plt.plot(x,y2, c='0.5', label='cos(x)',lw=3, ls='--')
plt.legend()
plt.show()

# %%
N = 16
for i in range(N):
    plt.gca().add_line(plt.Line2D((0,i),(N-i,0),color='0.75'))
    
plt.grid(True)
plt.axis('scaled')
plt.show()

# %%
shape = patches.Circle((0,0), radius=1, color='0.75')
plt.gca().add_patch(shape)

shape = patches.Rectangle((2.5,-.5),2,1,color='0.75')
plt.gca().add_patch(shape)

shape = patches.Ellipse((0,-2),2,1,angle=56, color='0.75')
plt.gca().add_patch(shape)

plt.grid(True)
plt.axis('scaled')
plt.show()

# %%
name_list = ('Omar','Serguey','Max','Zhou','Abidin')
value_list = np.random.randint(0,99, size = len(name_list))

pos_list = np.arange(len(name_list))

ax = plt.axes()
ax.xaxis.set_major_locator(ticker.FixedLocator((pos_list)))
ax.xaxis.set_major_formatter(ticker.FixedFormatter((name_list)))

plt.bar(pos_list, value_list, color='0.75', align= 'center')
plt.show()

# %%
name_list = ('Omar','Serguey','Max','Zhou','Abidin')
value_list = np.random.randint(0,99, size = len(name_list))

pos_list = np.arange(len(name_list))

plt.bar(pos_list,value_list, color='0.75', align='center')
plt.xticks(pos_list, name_list)
plt.show()
